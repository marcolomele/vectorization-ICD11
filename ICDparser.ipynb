# %% [markdown]
# If you are developing a tool that will require ICD-11 codes and the structure as shown in the ICD-11 Release then in the API you need to use the linearization endpoints with the linearizationname set to mms.

# %%
import requests
import json
import time
import os
import collections

# ========== CONFIGURATION ==========
CLIENT_ID = "6afc7b11-86c2-40f5-82d7-39c6c5869dec_38c25903-b150-4472-80cf-58648427fd58"
CLIENT_SECRET = "4kfkQUPOf4fBozRuZIMYsfff4n22mxUg/7dz85YXMqM="
TOKEN_ENDPOINT = 'https://icdaccessmanagement.who.int/connect/token'
ROOT_ENTITY_URI = 'https://id.who.int/icd/release/11/2023-01/mms'
MMS_BASE_URI = 'https://id.who.int/icd/release/11/2023-01/mms/'
OUTPUT_DIR = 'icd11_mms_crawled_entities'
SLEEP_TIME = 0.3  # To avoid rate limiting
MAX_ENTITIES = 1000  # Limit for fast test run
# ===================================

def get_access_token():
    payload = {
        'client_id': CLIENT_ID,
        'client_secret': CLIENT_SECRET,
        'scope': 'icdapi_access',
        'grant_type': 'client_credentials'
    }
    response = requests.post(TOKEN_ENDPOINT, data=payload)
    response.raise_for_status()
    token_data = response.json()
 
    return token_data['access_token']

def fetch_entity(entity_id, headers, visited, output_dir):
    if entity_id in visited:
        return
    visited.add(entity_id)

    uri = f'{MMS_BASE_URI}{entity_id}'
    response = requests.get(uri, headers=headers)
    if response.status_code != 200:
        print(f"⚠️ Failed to fetch {uri}")
        return

    data = response.json()
   

    with open(os.path.join(output_dir, f"{entity_id}.json"), 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    # Recurse into children (limit to 1 child per node for quick test)
    child_uris = data.get('child', [])[:1]
    for child_uri in child_uris:
        child_id = child_uri.split("/")[-1]
        time.sleep(SLEEP_TIME)
        fetch_entity(child_id, headers, visited, output_dir)

def crawl_icd11():
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    print("🔐 Getting access token...")
    token = get_access_token()

    headers = {
        'Authorization': f'Bearer {token}',
        'Accept': 'application/json',
        'Accept-Language': 'en',
        'API-Version': 'v2'
    }

    
    response = requests.get(ROOT_ENTITY_URI, headers=headers)
    root_data = response.json()
    root_children = root_data.get('child', [])

    root_ids = [uri.split('/')[-1] for uri in root_children[:MAX_ENTITIES]]
    with open("MMS_ROOTS.json", 'w') as f:
        json.dump(root_ids, f)

    visited = set()
    for entity_id in root_ids:
        fetch_entity(entity_id, headers, visited, OUTPUT_DIR)

    print(f"✅ Done! MMS linearized entities saved to '{OUTPUT_DIR}'")
crawl_icd11()
# Out:
# 🔐 Getting access token...
# ✅ Done! MMS linearized entities saved to 'icd11_mms_crawled_entities'

# %%
import os
import json
import pandas as pd

def extract_icd_text_data(json_folder):
    records = []

    for filename in os.listdir(json_folder):
        if not filename.endswith(".json"):
            continue
        filepath = os.path.join(json_folder, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            data = json.load(f)
        
        code = data.get("code", "")
        id_ = data.get("@id", "").split("/")[-1]
        title = data.get("title", {}).get("@value", "")
        definition = data.get("definition", {}).get("@value", "")
        
        # Collect synonyms if available
        synonyms = []
        for s in data.get("synonym", []):
            label = s.get("label", {}).get("@value")
            if label:
                synonyms.append(label)
        
        full_text = f"{title}. {definition} {' '.join(synonyms)}"

        records.append({
            "id": id_,
            "code": code,
            "title": title,
            "definition": definition,
            "synonyms": "; ".join(synonyms),
            "full_text": full_text
        })

    return pd.DataFrame(records)

# Usage
df = extract_icd_text_data("icd11_mms_crawled_entities")
#df.to_csv("icd11_text_data.csv", index=False)

# %%
df
# Out:
#             id     code                                              title  \
# 0   1028330801  3A00.01                   Chronic posthaemorrhagic anaemia
# 1    135352227                             Bacterial intestinal infections
# 2   1435254666       01           Certain infectious or parasitic diseases
# 3   1459690929  4A00.00               Neutrophil immunodeficiency syndrome
# 4   1577750667     3A00                            Iron deficiency anaemia
# 5   1630407678       02                                          Neoplasms
# 6   1719389232     2A00                         Primary neoplasms of brain
# 7   1722092627     5A00                                     Hypothyroidism
# 8   1766440644       03      Diseases of the blood or blood-forming organs
# 9   1907280211           Disorders of the thyroid gland or thyroid horm...
# 10  1954798891       04                      Diseases of the immune system
# 11    21500692       05       Endocrine, nutritional or metabolic diseases
# 12   224336967                     Anaemias or other erythrocyte disorders
# 13   234769120  5A00.00  Permanent congenital hypothyroidism with diffu...
# 14   257068234     1A00                                            Cholera
# 15   422307135   2A00.0                                   Gliomas of brain
# 16   461716838                                          Endocrine diseases
# 17   551037838     4A00  Primary immunodeficiencies due to disorders of...
# 18   587326822                                  Primary immunodeficiencies
# 19   588616678             Gastroenteritis or colitis of infectious origin
# 20   602450215   5A00.0                          Congenital hypothyroidism
# 21   650534447  2A00.00                              Glioblastoma of brain
# 22   808756909   4A00.0                      Functional neutrophil defects
# 23   879154182                Neoplasms of brain or central nervous system
# 24   942744561   3A00.0  Acquired iron deficiency anaemia due to blood ...
# 25   963670118                           Nutritional or metabolic anaemias
#
#                                            definition synonyms  \
# 0   Chronic iron-deficiency anaemia from bleeding ...
# 1   Any condition of the intestines, caused by an ...
# 2   This chapter includes certain conditions cause...
# 3   Neutrophil immunodeficiency syndrome is a prim...
# 4   A disease caused by chronic or acute bleeding,...
# 5   An abnormal or uncontrolled cellular prolifera...
# 6
# 7
# 8   This chapter includes diseases of the blood as...
# 9   Disorders due to dysfunction of thyroid gland ...
# 10
# 11  This chapter includes endocrine diseases, nutr...
# 12
# 13  A condition caused by a partial or complete lo...
# 14  Cholera is a potentially epidemic and life-thr...
# 15
# 16
# 17
# 18
# 19
# 20  Hypothyroidism is a condition where the thyroi...
# 21  Glioblastomas are malignant astrocytic tumours...
# 22
# 23  A benign or malignant neoplasm that affects th...
# 24  Chronic blood loss is a possible cause in ever...
# 25
#
#                                             full_text
# 0   Chronic posthaemorrhagic anaemia. Chronic iron...
# 1   Bacterial intestinal infections. Any condition...
# 2   Certain infectious or parasitic diseases. This...
# 3   Neutrophil immunodeficiency syndrome. Neutroph...
# 4   Iron deficiency anaemia. A disease caused by c...
# 5   Neoplasms. An abnormal or uncontrolled cellula...
# 6                       Primary neoplasms of brain.
# 7                                   Hypothyroidism.
# 8   Diseases of the blood or blood-forming organs....
# 9   Disorders of the thyroid gland or thyroid horm...
# 10                   Diseases of the immune system.
# 11  Endocrine, nutritional or metabolic diseases. ...
# 12         Anaemias or other erythrocyte disorders.
# 13  Permanent congenital hypothyroidism with diffu...
# 14  Cholera. Cholera is a potentially epidemic and...
# 15                                Gliomas of brain.
# 16                              Endocrine diseases.
# 17  Primary immunodeficiencies due to disorders of...
# 18                      Primary immunodeficiencies.
# 19  Gastroenteritis or colitis of infectious origi...
# 20  Congenital hypothyroidism. Hypothyroidism is a...
# 21  Glioblastoma of brain. Glioblastomas are malig...
# 22                   Functional neutrophil defects.
# 23  Neoplasms of brain or central nervous system. ...
# 24  Acquired iron deficiency anaemia due to blood ...
# 25               Nutritional or metabolic anaemias.
