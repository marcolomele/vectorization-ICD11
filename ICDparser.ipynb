# %% [markdown]
# # TODO:
# - farlo funzionare con tutti i nodi
# - includere le informazioni di passi intermedi
# - includere le informazioni dei collegamenti attraverso i nodi

# %% [markdown]
# If you are developing a tool that will require ICD-11 codes and the structure as shown in the ICD-11 Release then in the API you need to use the linearization endpoints with the linearizationname set to mms.

# %%
import requests
import json
import time
import os
import collections

# ========== CONFIGURATION ==========
CLIENT_ID = "6afc7b11-86c2-40f5-82d7-39c6c5869dec_38c25903-b150-4472-80cf-58648427fd58"
CLIENT_SECRET = "4kfkQUPOf4fBozRuZIMYsfff4n22mxUg/7dz85YXMqM="
TOKEN_ENDPOINT = 'https://icdaccessmanagement.who.int/connect/token'
ROOT_ENTITY_URI = 'https://id.who.int/icd/release/11/2023-01/mms'
MMS_BASE_URI = 'https://id.who.int/icd/release/11/2023-01/mms/'
OUTPUT_DIR = 'icd11_mms_crawled_entities'
SLEEP_TIME = 0.3  # To avoid rate limiting
MAX_ENTITIES = 26
# ===================================

def get_access_token():
    payload = {
        'client_id': CLIENT_ID,
        'client_secret': CLIENT_SECRET,
        'scope': 'icdapi_access',
        'grant_type': 'client_credentials'
    }
    response = requests.post(TOKEN_ENDPOINT, data=payload)
    response.raise_for_status()
    token_data = response.json()
 
    return token_data['access_token']

def fetch_entity(entity_id, headers, visited, output_dir):
    if entity_id in visited:
        return
    visited.add(entity_id)

    uri = f'{MMS_BASE_URI}{entity_id}'
    response = requests.get(uri, headers=headers)
    if response.status_code != 200:
        print(f"⚠️ Failed to fetch {uri}")
        return

    data = response.json()
   
    with open(os.path.join(output_dir, f"{entity_id}.json"), 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    # Recurse into children (limit to x children per node for quick test)
    child_per_node_limit = 2
    child_uris = data.get('child', [])[:child_per_node_limit]
    for child_uri in child_uris:
        child_id = child_uri.split("/")[-1]
        time.sleep(SLEEP_TIME)
        fetch_entity(child_id, headers, visited, output_dir)

def crawl_icd11():
    os.makedirs(OUTPUT_DIR, exist_ok=True)

    print("🔐 Getting access token...")
    token = get_access_token()

    headers = {
        'Authorization': f'Bearer {token}',
        'Accept': 'application/json',
        'Accept-Language': 'en',
        'API-Version': 'v2'
    }

    
    response = requests.get(ROOT_ENTITY_URI, headers=headers)
    root_data = response.json()
    root_children = root_data.get('child', [])

    root_ids = [uri.split('/')[-1] for uri in root_children[:MAX_ENTITIES]]
    with open("MMS_ROOTS.json", 'w') as f:
        json.dump(root_ids, f)

    visited = set()
    for entity_id in root_ids:
        fetch_entity(entity_id, headers, visited, OUTPUT_DIR)

    print(f"✅ Done! MMS linearized entities saved to '{OUTPUT_DIR}'")
    
crawl_icd11()
# Out:
# 🔐 Getting access token...
# ⚠️ Failed to fetch https://id.who.int/icd/release/11/2023-01/mms/other
# ⚠️ Failed to fetch https://id.who.int/icd/release/11/2023-01/mms/unspecified
# ✅ Done! MMS linearized entities saved to 'icd11_mms_crawled_entities'

# %%
import os
import json
import pandas as pd

def extract_icd_text_data(json_folder):
    records = []

    for filename in os.listdir(json_folder):
        if not filename.endswith(".json"):
            continue
        filepath = os.path.join(json_folder, filename)
        with open(filepath, "r", encoding="utf-8") as f:
            data = json.load(f)
        
        code = data.get("code", "")
        id_ = data.get("@id", "").split("/")[-1]
        title = data.get("title", {}).get("@value", "")
        definition = data.get("definition", {}).get("@value", "")
        
        # Collect synonyms if available
        synonyms = []
        for s in data.get("synonym", []):
            label = s.get("label", {}).get("@value")
            if label:
                synonyms.append(label)
        
        full_text = f"{title}. {definition} {' '.join(synonyms)}"

        records.append({
            "id": id_,
            "code": code,
            "title": title,
            "definition": definition,
            "synonyms": "; ".join(synonyms),
            "full_text": full_text
        })

    return pd.DataFrame(records)

# Usage
df = extract_icd_text_data("icd11_mms_crawled_entities")
#df.to_csv("icd11_text_data.csv", index=False)

# %%
df.sort_values(by="code", inplace=True)
df[df['code'] != ''].iloc[-50:]
# Out:
#               id    code                                              title  \
# 929   1704767204  NA21.0            Laceration without foreign body of neck
# 587   1193245831  NA21.1               Laceration with foreign body of neck
# 295   1114138453    PA00  Unintentional land transport traffic event inj...
# 441   1460349350    PA01  Unintentional land transport traffic event inj...
# 287   1595005935    PA10  Unintentional land transport nontraffic event ...
# 939   2133070765    PA11  Unintentional land transport nontraffic event ...
# 427    415990995    PA60  Unintentional fall on the same level or from l...
# 728   1729453916    PA61  Unintentional fall from a height of 1 metre or...
# 318   1494862045    PB80  Intentional self-harm by land transport road t...
# 1223   110743840    PB81  Intentional self-harm by land transport off-ro...
# 651    244051855    PC30  Intentional self-harm by fall or jump on same ...
# 41    1039175191    PC31  Intentional self-harm by fall or jump from a h...
# 988   1865167886    QA00  General examination or investigation of person...
# 269   1987210192  QA00.0                  General adult medical examination
# 897    322545222  QA00.1                   Routine child health examination
# 775   2127210855    QA01  Examination or encounter for administrative pu...
# 271   1796014959  QA01.0  Examination for admission to educational insti...
# 293    239521531  QA01.1                         Pre-employment examination
# 351   1851857465    QA10  Contact with health services for dietary couns...
# 673    495946157    QA11  Contact with health services for alcohol use c...
# 424    755867815    QD50                                            Poverty
# 20    1503719512    QD51                                         Low income
# 1022  1163409625    QD60  Problems associated with inadequate drinking-w...
# 13    1212575027    QD61                                    Inadequate food
# 750   2103512582    RA00  Conditions of uncertain aetiology and emergenc...
# 112   1880731274  RA00.0                            Vaping related disorder
# 1277  1730556128    RA01                                           COVID-19
# 1153  1790791774  RA01.0                         COVID-19, virus identified
# 924    563410356  RA01.1                     COVID-19, virus not identified
# 729    471849326    RA20                         National emergency code 01
# 1236  1400642551    RA21                         National emergency code 02
# 1146  1698745907    SA00                  Hypochondrium pain disorder (TM1)
# 1102  1514919681    SA01                            Jaundice disorder (TM1)
# 406    846189212    SA10               Inducible palpitation disorder (TM1)
# 1259  1070055580    SA11             Spontaneous palpitation disorder (TM1)
# 930    869937025    SA20                     True heart pain disorder (TM1)
# 1007  1512913627    SB30                       Dampness sore disorder (TM1)
# 492   1868532835    SB31                            Impetigo disorder (TM1)
# 15    1238772413    SB80               Advanced menstruation disorder (TM1)
# 337   1258827162    SB81                Delayed menstruation disorder (TM1)
# 860   2003357330    SB90                         Menorrhagia disorder (TM1)
# 247    105047793    SC00                    Morning sickness disorder (TM1)
# 483   2122522849    SC01                      Unstable fetus disorder (TM1)
# 452   1784846003    SE70                                 Yang pattern (TM1)
# 1160  1249733117    SE71                                  Yin pattern (TM1)
# 1263   613042039    SE80                          Wind factor pattern (TM1)
# 471   1217643405    SE81                          Cold factor pattern (TM1)
# 927    231358748       V   Supplementary section for functioning assessment
# 753    532448599    VD00                       Attention functions [WHODAS]
# 1182   979408586       X                                    Extension Codes
#
#                                              definition synonyms  \
# 929
# 587
# 295
# 441
# 287
# 939
# 427
# 728
# 318
# 1223
# 651
# 41
# 988
# 269   Encounter for periodic examination (annual) (p...
# 897   Routine health check for child over 28 days of...
# 775
# 271
# 293
# 351
# 673
# 424
# 20
# 1022
# 13
# 750
# 112   Disorder resulting from inhaling a vaporized s...
# 1277  As definition may evolve, the URL for the Glob...
# 1153
# 924
# 729
# 1236
# 1146
# 1102
# 406
# 1259
# 930
# 1007
# 492
# 15
# 337
# 860
# 247
# 483
# 452
# 1160
# 1263
# 471
# 927   The section allows for creating functioning pr...
# 753   Because of your health condition, in the past ...
# 1182  !markdown\nExtension codes should never be use...
#
#                                               full_text
# 929          Laceration without foreign body of neck.
# 587             Laceration with foreign body of neck.
# 295   Unintentional land transport traffic event inj...
# 441   Unintentional land transport traffic event inj...
# 287   Unintentional land transport nontraffic event ...
# 939   Unintentional land transport nontraffic event ...
# 427   Unintentional fall on the same level or from l...
# 728   Unintentional fall from a height of 1 metre or...
# 318   Intentional self-harm by land transport road t...
# 1223  Intentional self-harm by land transport off-ro...
# 651   Intentional self-harm by fall or jump on same ...
# 41    Intentional self-harm by fall or jump from a h...
# 988   General examination or investigation of person...
# 269   General adult medical examination. Encounter f...
# 897   Routine child health examination. Routine heal...
# 775   Examination or encounter for administrative pu...
# 271   Examination for admission to educational insti...
# 293                       Pre-employment examination.
# 351   Contact with health services for dietary couns...
# 673   Contact with health services for alcohol use c...
# 424                                          Poverty.
# 20                                        Low income.
# 1022  Problems associated with inadequate drinking-w...
# 13                                   Inadequate food.
# 750   Conditions of uncertain aetiology and emergenc...
# 112   Vaping related disorder. Disorder resulting fr...
# 1277  COVID-19. As definition may evolve, the URL fo...
# 1153                      COVID-19, virus identified.
# 924                   COVID-19, virus not identified.
# 729                       National emergency code 01.
# 1236                      National emergency code 02.
# 1146               Hypochondrium pain disorder (TM1).
# 1102                         Jaundice disorder (TM1).
# 406             Inducible palpitation disorder (TM1).
# 1259          Spontaneous palpitation disorder (TM1).
# 930                   True heart pain disorder (TM1).
# 1007                    Dampness sore disorder (TM1).
# 492                          Impetigo disorder (TM1).
# 15              Advanced menstruation disorder (TM1).
# 337              Delayed menstruation disorder (TM1).
# 860                       Menorrhagia disorder (TM1).
# 247                  Morning sickness disorder (TM1).
# 483                    Unstable fetus disorder (TM1).
# 452                               Yang pattern (TM1).
# 1160                               Yin pattern (TM1).
# 1263                       Wind factor pattern (TM1).
# 471                        Cold factor pattern (TM1).
# 927   Supplementary section for functioning assessme...
# 753   Attention functions [WHODAS]. Because of your ...
# 1182  Extension Codes. !markdown\nExtension codes sh...
