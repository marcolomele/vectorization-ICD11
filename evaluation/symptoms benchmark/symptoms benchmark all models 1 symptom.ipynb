# %%
import pandas as pd
import numpy as np
import ast
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import display

# === Step 1: Load ICD11 code → title map once ===
lookup_df = pd.read_csv("icd11-25_data_vectorization.csv")
title_map = dict(zip(lookup_df["code"], lookup_df["title"]))

# === Step 2: Generate list of single symptoms ===
def generate_symptom_list(embedding_files, random_state=None):
    if random_state is not None:
        np.random.seed(random_state)
    m_sets = []
    for f in embedding_files:
        df = pd.read_csv(f).dropna(subset=["ICD11_code"])
        m_sets.append(set(df[df['ICD11_code'].str.startswith('M')]['ICD11_code']))
    common = sorted(set.intersection(*m_sets))
    if not common:
        raise ValueError("No common M-codes found across embedding files.")
    return common

# === Step 3: Single-model best match for each symptom ===
def best_match_for_symptoms(emb_file, symptoms, title_map):
    df = pd.read_csv(emb_file).dropna(subset=["ICD11_code"])
    vec_col = 'Vector' if 'Vector' in df.columns else 'vector'
    def parse_vector(cell):
        if isinstance(cell, str):
            try:
                return np.array(ast.literal_eval(cell), dtype=float)
            except:
                parts = cell.strip('[]').replace(',', ' ').split()
                return np.array([float(x) for x in parts], dtype=float)
        elif isinstance(cell, (list, np.ndarray)):
            return np.array(cell, dtype=float)
        else:
            raise ValueError(f"Unknown vector format: {type(cell)}")
    df['vector'] = df[vec_col].apply(parse_vector)

    m_df = df[df['ICD11_code'].str.startswith('M')]
    non_m_df = df[~df['ICD11_code'].str.startswith('M')]
    m2v = dict(zip(m_df['ICD11_code'], m_df['vector']))
    non2v = dict(zip(non_m_df['ICD11_code'], non_m_df['vector']))
    non_codes = list(non2v.keys())
    disease_stack = np.vstack([non2v[c] for c in non_codes])

    results = []
    for sym in symptoms:
        vec = m2v[sym]
        sims = cosine_similarity([vec], disease_stack)[0]
        idx = np.argmax(sims)
        code = non_codes[idx]
        score = sims[idx]
        title = title_map.get(code, '(title not found)')
        results.append((sym, code, title, score))
    return results

# === Step 4: Execute benchmarking and build raw dataframes ===
embedding_files = [
    "tfidf_ICD11_embeddings.csv",
    "fasttext_ICD11_embeddings.csv",
    "bert_ICD11_embeddings.csv",
    "biobert_ICD11_embeddings.csv",
    "bioclinicalbert_ICD11_embeddings.csv",
    "pubmedbert_ICD11_embeddings.csv",
    "gatortron_ICD11_embeddings.csv"
]
model_names = [f.split('_')[0] for f in embedding_files]

# Generate common symptom list
symptoms = generate_symptom_list(embedding_files, random_state=42)

# Get predictions per model
per_model = {
    name: best_match_for_symptoms(f, symptoms, title_map)
    for name, f in zip(model_names, embedding_files)
}

# Build codes_df and scores_df
codes_df = pd.DataFrame({
    name: [res[i][1] for i in range(len(symptoms))]
    for name, res in per_model.items()
}, index=symptoms)

scores_df = pd.DataFrame({
    name: [res[i][3] for i in range(len(symptoms))]
    for name, res in per_model.items()
}, index=symptoms)

# === Step 5: Build and save combined benchmarking table ===
combined_table = pd.DataFrame({
    'Symptom': [f"{sym} ({title_map.get(sym)})" for sym in symptoms]
})
for name in model_names:
    combined_table[f"{name} (CS)"] = [
        f"{codes_df.loc[sym, name]} ({title_map.get(codes_df.loc[sym, name])}) ({scores_df.loc[sym, name]:.2f})"
        for sym in symptoms
    ]
# Compute consensus counts
consensus_counts = codes_df.apply(lambda row: row.value_counts().max(), axis=1)
combined_table['Consensus Count'] = consensus_counts.values

combined_table.to_csv("benchmarking_results.csv", index=False)
print("Saved benchmarking_results.csv with full table.")

# === Step 6: Summary statistics ===
# 1. Mean & std per model
print("Mean and Standard Deviation of Cosine Similarity per Model:")
for name in model_names:
    mean = scores_df[name].mean()
    std = scores_df[name].std()
    print(f"- {name}: mean={mean:.4f}, std={std:.4f}")
print()

# 2. Consensus distribution
print("Distribution of Consensus Count:")
print(consensus_counts.value_counts().sort_index().to_string())
print()

# 3. Agreement matrix with conditional formatting
agree_mat = pd.DataFrame(index=model_names, columns=model_names, dtype=float)
for m1 in model_names:
    for m2 in model_names:
        agree_mat.loc[m1, m2] = round((codes_df[m1] == codes_df[m2]).mean() * 100, 2)

print("Agreement Matrix (% exact matches):")
styled = (
    agree_mat.style
        .format("{:.2f}")
        .background_gradient(axis=None, cmap='Greens', low=0.2, high=0.8)
        .highlight_max(axis=1, color='lightgreen')
        .set_properties(**{
            'min-width': '150px',
            'max-width': '150px',
            'text-align': 'center'
        })
        .set_table_styles([
            {'selector': 'th', 'props': [('text-align', 'center')]}
        ], overwrite=False)
)
display(styled)
# Out:
# Saved benchmarking_results.csv with full table.
# Mean and Standard Deviation of Cosine Similarity per Model:
# - tfidf: mean=0.6158, std=0.1340
# - fasttext: mean=0.9754, std=0.0101
# - bert: mean=0.9600, std=0.0137
# - biobert: mean=0.9791, std=0.0076
# - bioclinicalbert: mean=0.9768, std=0.0068
# - pubmedbert: mean=0.9952, std=0.0017
# - gatortron: mean=0.9648, std=0.0138
#
# Distribution of Consensus Count:
# 1     87
# 2    272
# 3    239
# 4    118
# 5     99
# 6     69
# 7     55
#
# Agreement Matrix (% exact matches):
# <style type="text/css">
# #T_485ef th {
#   text-align: center;
# }
# #T_485ef_row0_col0, #T_485ef_row1_col1, #T_485ef_row2_col2, #T_485ef_row3_col3, #T_485ef_row4_col4, #T_485ef_row5_col5, #T_485ef_row6_col6 {
#   background-color: #4bb062;
#   color: #f1f1f1;
#   background-color: lightgreen;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row0_col1, #T_485ef_row1_col0 {
#   background-color: #e3f4de;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row0_col2, #T_485ef_row2_col0 {
#   background-color: #e8f6e3;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row0_col3, #T_485ef_row3_col0 {
#   background-color: #e7f6e3;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row0_col4, #T_485ef_row4_col0 {
#   background-color: #e9f7e5;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row0_col5, #T_485ef_row5_col0 {
#   background-color: #e5f5e0;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row0_col6, #T_485ef_row6_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row1_col2, #T_485ef_row2_col1 {
#   background-color: #def2d9;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row1_col3, #T_485ef_row3_col1, #T_485ef_row4_col6, #T_485ef_row6_col4 {
#   background-color: #dbf1d6;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row1_col4, #T_485ef_row4_col1 {
#   background-color: #e4f5df;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row1_col5, #T_485ef_row5_col1 {
#   background-color: #d9f0d3;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row1_col6, #T_485ef_row6_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row2_col3, #T_485ef_row3_col2 {
#   background-color: #d1edcb;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row2_col4, #T_485ef_row2_col6, #T_485ef_row4_col2, #T_485ef_row6_col2 {
#   background-color: #d7efd1;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row2_col5, #T_485ef_row5_col2 {
#   background-color: #d5efcf;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row3_col4, #T_485ef_row4_col3 {
#   background-color: #d6efd0;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row3_col5, #T_485ef_row5_col3 {
#   background-color: #cfecc9;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row3_col6, #T_485ef_row6_col3 {
#   background-color: #d2edcc;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row4_col5, #T_485ef_row5_col4 {
#   background-color: #dcf2d7;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# #T_485ef_row5_col6, #T_485ef_row6_col5 {
#   background-color: #cbebc5;
#   color: #000000;
#   min-width: 150px;
#   max-width: 150px;
#   text-align: center;
# }
# </style>
# <table id="T_485ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_485ef_level0_col0" class="col_heading level0 col0" >tfidf</th>
#       <th id="T_485ef_level0_col1" class="col_heading level0 col1" >fasttext</th>
#       <th id="T_485ef_level0_col2" class="col_heading level0 col2" >bert</th>
#       <th id="T_485ef_level0_col3" class="col_heading level0 col3" >biobert</th>
#       <th id="T_485ef_level0_col4" class="col_heading level0 col4" >bioclinicalbert</th>
#       <th id="T_485ef_level0_col5" class="col_heading level0 col5" >pubmedbert</th>
#       <th id="T_485ef_level0_col6" class="col_heading level0 col6" >gatortron</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_485ef_level0_row0" class="row_heading level0 row0" >tfidf</th>
#       <td id="T_485ef_row0_col0" class="data row0 col0" >100.00</td>
#       <td id="T_485ef_row0_col1" class="data row0 col1" >21.73</td>
#       <td id="T_485ef_row0_col2" class="data row0 col2" >17.25</td>
#       <td id="T_485ef_row0_col3" class="data row0 col3" >17.89</td>
#       <td id="T_485ef_row0_col4" class="data row0 col4" >16.08</td>
#       <td id="T_485ef_row0_col5" class="data row0 col5" >20.55</td>
#       <td id="T_485ef_row0_col6" class="data row0 col6" >22.68</td>
#     </tr>
#     <tr>
#       <th id="T_485ef_level0_row1" class="row_heading level0 row1" >fasttext</th>
#       <td id="T_485ef_row1_col0" class="data row1 col0" >21.73</td>
#       <td id="T_485ef_row1_col1" class="data row1 col1" >100.00</td>
#       <td id="T_485ef_row1_col2" class="data row1 col2" >25.45</td>
#       <td id="T_485ef_row1_col3" class="data row1 col3" >27.48</td>
#       <td id="T_485ef_row1_col4" class="data row1 col4" >21.09</td>
#       <td id="T_485ef_row1_col5" class="data row1 col5" >29.29</td>
#       <td id="T_485ef_row1_col6" class="data row1 col6" >26.09</td>
#     </tr>
#     <tr>
#       <th id="T_485ef_level0_row2" class="row_heading level0 row2" >bert</th>
#       <td id="T_485ef_row2_col0" class="data row2 col0" >17.25</td>
#       <td id="T_485ef_row2_col1" class="data row2 col1" >25.45</td>
#       <td id="T_485ef_row2_col2" class="data row2 col2" >100.00</td>
#       <td id="T_485ef_row2_col3" class="data row2 col3" >34.61</td>
#       <td id="T_485ef_row2_col4" class="data row2 col4" >30.67</td>
#       <td id="T_485ef_row2_col5" class="data row2 col5" >31.52</td>
#       <td id="T_485ef_row2_col6" class="data row2 col6" >30.67</td>
#     </tr>
#     <tr>
#       <th id="T_485ef_level0_row3" class="row_heading level0 row3" >biobert</th>
#       <td id="T_485ef_row3_col0" class="data row3 col0" >17.89</td>
#       <td id="T_485ef_row3_col1" class="data row3 col1" >27.48</td>
#       <td id="T_485ef_row3_col2" class="data row3 col2" >34.61</td>
#       <td id="T_485ef_row3_col3" class="data row3 col3" >100.00</td>
#       <td id="T_485ef_row3_col4" class="data row3 col4" >31.31</td>
#       <td id="T_485ef_row3_col5" class="data row3 col5" >35.46</td>
#       <td id="T_485ef_row3_col6" class="data row3 col6" >33.76</td>
#     </tr>
#     <tr>
#       <th id="T_485ef_level0_row4" class="row_heading level0 row4" >bioclinicalbert</th>
#       <td id="T_485ef_row4_col0" class="data row4 col0" >16.08</td>
#       <td id="T_485ef_row4_col1" class="data row4 col1" >21.09</td>
#       <td id="T_485ef_row4_col2" class="data row4 col2" >30.67</td>
#       <td id="T_485ef_row4_col3" class="data row4 col3" >31.31</td>
#       <td id="T_485ef_row4_col4" class="data row4 col4" >100.00</td>
#       <td id="T_485ef_row4_col5" class="data row4 col5" >26.30</td>
#       <td id="T_485ef_row4_col6" class="data row4 col6" >26.94</td>
#     </tr>
#     <tr>
#       <th id="T_485ef_level0_row5" class="row_heading level0 row5" >pubmedbert</th>
#       <td id="T_485ef_row5_col0" class="data row5 col0" >20.55</td>
#       <td id="T_485ef_row5_col1" class="data row5 col1" >29.29</td>
#       <td id="T_485ef_row5_col2" class="data row5 col2" >31.52</td>
#       <td id="T_485ef_row5_col3" class="data row5 col3" >35.46</td>
#       <td id="T_485ef_row5_col4" class="data row5 col4" >26.30</td>
#       <td id="T_485ef_row5_col5" class="data row5 col5" >100.00</td>
#       <td id="T_485ef_row5_col6" class="data row5 col6" >38.02</td>
#     </tr>
#     <tr>
#       <th id="T_485ef_level0_row6" class="row_heading level0 row6" >gatortron</th>
#       <td id="T_485ef_row6_col0" class="data row6 col0" >22.68</td>
#       <td id="T_485ef_row6_col1" class="data row6 col1" >26.09</td>
#       <td id="T_485ef_row6_col2" class="data row6 col2" >30.67</td>
#       <td id="T_485ef_row6_col3" class="data row6 col3" >33.76</td>
#       <td id="T_485ef_row6_col4" class="data row6 col4" >26.94</td>
#       <td id="T_485ef_row6_col5" class="data row6 col5" >38.02</td>
#       <td id="T_4
