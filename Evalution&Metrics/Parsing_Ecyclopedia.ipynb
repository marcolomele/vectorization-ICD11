# %% [markdown]
# # Medical Term Definition Analysis for ICD-11 Codes
#
# This notebook processes single-word medical terms from ICD-11 classification and retrieves their definitions from Merriam-Webster's Medical Dictionary API. The workflow includes:
#
# - Loading and filtering single-word medical terms from ICD-11 dataset
# - Fetching definitions using Merriam-Webster's Medical Dictionary API
# - Processing and cleaning the retrieved definitions
# - Creating a mapping between ICD-11 codes and their corresponding medical definitions
# - Filtering for terms with single, unambiguous definitions for further analysis

# %%
import pandas as pd

df = pd.read_csv("Bert_new_embeddings/icd11-25_data_raw.csv")
print("Loaded CSV from Bert_new_embeddings/icd11-25_data_raw.csv")
# Out:
# Loaded CSV from Bert_new_embeddings/icd11-25_data_raw.csv

# %%
# Count number of words in each title
df['title_word_count'] = df['title'].str.split().str.len()

# Show counts for 1-word, 2-word, etc.
word_count_stats = df['title_word_count'].value_counts().sort_index()
print("Number of titles by word count:")
print(word_count_stats)

# Filter only titles with one word
one_word_titles = df[df['title_word_count'] == 1][['title', 'code']]
print(f"\nNumber of one-word titles: {len(one_word_titles)}")

# Save to CSV
one_word_titles.to_csv('one_word_icd11_titles_codes.csv', index=False)
# Out:
# Number of titles by word count:
# title_word_count
# 1      749
# 2     1963
# 3     2301
# 4     2115
# 5     1748
# 6     1394
# 7     1039
# 8      830
# 9      553
# 10     385
# 11     269
# 12     175
# 13     115
# 14      96
# 15      80
# 16      52
# 17      42
# 18      19
# 19      12
# 20       6
# 21       9
# 22       2
# 23       2
# 24       1
# 25       1
# 26       1
# 29       1
# Name: count, dtype: int64
#
# Number of one-word titles: 749

# %%
one_word_titles[one_word_titles["title"] == 'Helminthiases']
# Out:
#              title code
# 145  Helminthiases  NaN

# %%
import time
import requests
import csv
from urllib.parse import quote_plus
import pandas as pd

# 1) Load your sample and extract disease list
diseases = one_word_titles['title'].tolist()
# diseases = ['Typhoid']

# 2) API settings
API_KEY = "0cca9c9d-16e4-4f16-b77a-d0d0c681348a"
BASE_URL = "https://www.dictionaryapi.com/api/v3/references/medical/json/{}?key={}"

# 3) Helper to fetch definitions for one term
def fetch_definitions(term):
    """Return a list of all shortdef strings for 'term'."""
    url_term = quote_plus(term)
    url = BASE_URL.format(url_term, API_KEY)
    resp = requests.get(url, timeout=10)
    resp.raise_for_status()
    data = resp.json()
    
    definitions = []
    # The API may return suggestions (strings) if no entry found,
    # so we only process dict entries that have 'shortdef'.
    for entry in data:
        if isinstance(entry, dict) and 'shortdef' in entry:
            definitions.extend(entry['shortdef'])
    return definitions

# 4) Main loop: query each disease, save to CSV
with open("diseases_definitions.csv", "w", newline="", encoding="utf-8") as fout:
    writer = csv.writer(fout)
    writer.writerow(["Disease", "Definitions"])
    
    for disease in diseases:
        print(f"Looking up: {disease}")
        try:
            defs = fetch_definitions(disease)
            if defs:
                # join multiple defs with semicolon
                defs_text = "; ".join(defs)
            else:
                defs_text = ""
            writer.writerow([disease, defs_text])
            print(f"  → Retrieved {len(defs)} definitions.")
        except Exception as e:
            print(f"  ⚠️ Error for '{disease}': {e}")
            writer.writerow([disease, "ERROR: " + str(e)])
        
        # be polite to the API
        time.sleep(0.5)

print("Done! Results in diseases_definitions.csv")
# Out:
# Looking up: Toxoplasmosis
#   → Retrieved 1 definitions.
# Looking up: Tetanus
#   → Retrieved 7 definitions.
# Looking up: Lobomycosis
#   → Retrieved 0 definitions.
# Looking up: Babesiosis
#   → Retrieved 3 definitions.
# Looking up: Varicella
#   → Retrieved 3 definitions.
# Looking up: Rickettsialpox
#   → Retrieved 1 definitions.
# Looking up: Leptospirosis
#   → Retrieved 1 definitions.
# Looking up: Phaeohyphomycosis
#   → Retrieved 0 definitions.
# Looking up: Clonorchiasis
#   → Retrieved 1 definitions.
# Looking up: Cimicosis
#   → Retrieved 0 definitions.
# Looking up: Giardiasis
#   → Retrieved 1 definitions.
# Looking up: Gnathostomiasis
#   → Retrieved 1 definitions.
# Looking up: Actinomycosis
#   → Retrieved 1 definitions.
# Looking up: Ascariasis
#   → Retrieved 1 definitions.
# Looking up: Buffalopox
#   → Retrieved 0 definitions.
# Looking up: Angiostrongyliasis
#   → Retrieved 0 definitions.
# Looking up: Onchocerciasis
#   → Retrieved 1 definitions.
# Looking up: Measles
#   → Retrieved 6 definitions.
# Looking up: Leprosy
#   → Retrieved 4 definitions.
# Looking up: Cryptosporidiosis
#   → Retrieved 1 definitions.
# Looking up: Dicrocoeliasis
#   → Retrieved 0 definitions.
# Looking up: Helminthiases
#   → Retrieved 1 definitions.
# Looking up: Mumps
#   → Retrieved 1 definitions.
# Looking up: Sparganosis
#   → Retrieved 1 definitions.
# Looking up: Capillariasis
#   → Retrieved 1 definitions.
# Looking up: Tuberculosis
#   → Retrieved 3 definitions.
# Looking up: Myiasis
#   → Retrieved 1 definitions.
# Looking up: Aspergillosis
#   → Retrieved 1 definitions.
# Looking up: Rabies
#   → Retrieved 5 definitions.
# Looking up: Taeniasis
#   → Retrieved 1 definitions.
# Looking up: Filariasis
#   → Retrieved 2 definitions.
# Looking up: Diphyllobothriasis
#   → Retrieved 1 definitions.
# Looking up: Anisakiasis
#   → Retrieved 1 definitions.
# Looking up: Talaromycosis
#   → Retrieved 0 definitions.
# Looking up: Tungiasis
#   → Retrieved 0 definitions.
# Looking up: Spirillosis
#   → Retrieved 1 definitions.
# Looking up: Dracunculiasis
#   → Retrieved 1 definitions.
# Looking up: Emmonsiosis
#   → Retrieved 0 definitions.
# Looking up: Syngamosis
#   → Retrieved 1 definitions.
# Looking up: Leishmaniasis
#   → Retrieved 5 definitions.
# Looking up: Scedosporiosis
#   → Retrieved 0 definitions.
# Looking up: Sporotrichosis
#   → Retrieved 1 definitions.
# Looking up: Glanders
#   → Retrieved 3 definitions.
# Looking up: Blastomycosis
#   → Retrieved 3 definitions.
# Looking up: Vaccinia
#   → Retrieved 5 definitions.
# Looking up: Loiasis
#   → Retrieved 1 definitions.
# Looking up: Furuncle
#   → Retrieved 2 definitions.
# Looking up: Trichuriasis
#   → Retrieved 1 definitions.
# Looking up: Chancroid
#   → Retrieved 1 definitions.
# Looking up: Cowpox
#   → Retrieved 3 definitions.
# Looking up: Amoebiasis
#   → Retrieved 1 definitions.
# Looking up: Mpox
#   → Retrieved 1 definitions.
# Looking up: Cystoisosporiasis
#   → Retrieved 0 definitions.
# Looking up: Orf
#   → Retrieved 4 definitions.
# Looking up: Sepsis
#   → Retrieved 3 definitions.
# Looking up: Bartonellosis
#   → Retrieved 1 definitions.
# Looking up: Eumycetoma
#   → Retrieved 0 definitions.
# Looking up: Basidiobolomycosis
#   → Retrieved 0 definitions.
# Looking up: Trichomoniasis
#   → Retrieved 3 definitions.
# Looking up: Histoplasmosis
#   → Retrieved 1 definitions.
# Looking up: Rhinosporidiosis
#   → Retrieved 1 definitions.
# Looking up: Dipylidiasis
#   → Retrieved 1 definitions.
# Looking up: Mansonelliasis
#   → Retrieved 0 definitions.
# Looking up: Strongyloidiasis
#   → Retrieved 2 definitions.
# Looking up: Chromoblastomycosis
#   → Retrieved 1 definitions.
# Looking up: Mucormycosis
#   → Retrieved 1 definitions.
# Looking up: Candidosis
#   → Retrieved 0 definitions.
# Looking up: Brucellosis
#   → Retrieved 2 definitions.
# Looking up: Diphtheria
#   → Retrieved 2 definitions.
# Looking up: Malaria
#   → Retrieved 11 definitions.
# Looking up: Dermatophytosis
#   → Retrieved 1 definitions.
# Looking up: Paracoccidioidomycosis
#   → Retrieved 2 definitions.
# Looking up: Influenza
#   → Retrieved 14 definitions.
# Looking up: Pediculosis
#   → Retrieved 4 definitions.
# Looking up: Oesophagostomiasis
#   → Retrieved 1 definitions.
# Looking up: Rubella
#   → Retrieved 3 definitions.
# Looking up: Pthiriasis
#   → Retrieved 0 definitions.
# Looking up: Yaws
#   → Retrieved 3 definitions.
# Looking up: Impetigo
#   → Retrieved 2 definitions.
# Looking up: Trichostrongyliasis
#   → Retrieved 0 definitions.
# Looking up: Microsporidiosis
#   → Retrieved 1 definitions.
# Looking up: Fasciolopsiasis
#   → Retrieved 1 definitions.
# Looking up: Fascioliasis
#   → Retrieved 1 definitions.
# Looking up: Smallpox
#   → Retrieved 1 definitions.
# Looking up: Plague
#   → Retrieved 12 definitions.
# Looking up: Legionellosis
#   → Retrieved 1 definitions.
# Looking up: Anthrax
#   → Retrieved 4 definitions.
# Looking up: Erysipelas
#   → Retrieved 3 definitions.
# Looking up: Sarcocystosis
#   → Retrieved 1 definitions.
# Looking up: Neurosyphilis
#   → Retrieved 1 definitions.
# Looking up: Hymenolepiasis
#   → Retrieved 1 definitions.
# Looking up: Melioidosis
#   → Retrieved 1 definitions.
# Looking up: Protothecosis
#   → Retrieved 1 definitions.
# Looking up: Toxocariasis
#   → Retrieved 1 definitions.
# Looking up: Rickettsioses
#   → Retrieved 1 definitions.
# Looking up: Furunculosis
#   → Retrieved 2 definitions.
# Looking up: Echinococcosis
#   → Retrieved 1 definitions.
# Looking up: Tularaemia
#   → Retrieved 1 definitions.
# Looking up: Campylobacteriosis
#   → Retrieved 1 definitions.
# Looking up: Dengue
#   → Retrieved 3 definitions.
# Looking up: Nocardiosis
#   → Retrieved 1 definitions.
# Looking up: Paragonimiasis
#   → Retrieved 1 definitions.
# Looking up: Opisthorchiasis
#   → Retrieved 1 definitions.
# Looking up: Carbuncle
#   → Retrieved 1 definitions.
# Looking up: Trichinosis
#   → Retrieved 1 definitions.
# Looking up: Erysipeloid
#   → Retrieved 2 definitions.
# Looking up: Mycoses
#   → Retrieved 1 definitions.
# Looking up: Acanthamoebiasis
#   → Retrieved 0 definitions.
# Looking up: Syphilis
#   → Retrieved 6 definitions.
# Looking up: Pythiosis
#   → Retrieved 0 definitions.
# Looking up: Streptobacillosis
#   → Retrieved 0 definitions.
# Looking up: Cholera
#   → Retrieved 12 definitions.
# Looking up: Botulism
#   → Retrieved 1 definitions.
# Looking up: Enterobiasis
#   → Retrieved 1 definitions.
# Looking up: Trachoma
#   → Retrieved 1 definitions.
# Looking up: Conidiobolomycosis
#   → Retrieved 0 definitions.
# Looking up: Blastocystosis
#   → Retrieved 0 definitions.
# Looking up: Pinta
#   → Retrieved 1 definitions.
# Looking up: Cryptococcosis
#   → Retrieved 1 definitions.
# Looking up: Naegleriasis
#   → Retrieved 0 definitions.
# Looking up: Listeriosis
#   → Retrieved 1 definitions.
# Looking up: Uncinariosis
#   → Retrieved 0 definitions.
# Looking up: Kerion
#   → Retrieved 1 definitions.
# Looking up: Necatoriasis
#   → Retrieved 1 definitions.
# Looking up: Meningococcaemia
#   → Retrieved 1 definitions.
# Looking up: Cysticercosis
#   → Retrieved 1 definitions.
# Looking up: Ancylostomiasis
#   → Retrieved 1 definitions.
# Looking up: Coccidioidomycosis
#   → Retrieved 1 definitions.
# Looking up: Zoster
#   → Retrieved 5 definitions.
# Looking up: Actinomycetoma
#   → Retrieved 0 definitions.
# Looking up: Pneumocystosis
#   → Retrieved 0 definitions.
# Looking up: Pasteurellosis
#   → Retrieved 1 definitions.
# Looking up: Schistosomiasis
#   → Retrieved 4 definitions.
# Looking up: Scabies
#   → Retrieved 1 definitions.
# Looking up: Ecthyma
#   → Retrieved 2 definitions.
# Looking up: Petrositis
#   → Retrieved 1 definitions.
# Looking up: Labyrinthitis
#   → Retrieved 1 definitions.
# Looking up: Presbycusis
#   → Retrieved 1 definitions.
# Looking up: Tympanosclerosis
#   → Retrieved 0 definitions.
# Looking up: Otomycosis
#   → Retrieved 1 definitions.
# Looking up: Otalgia
#   → Retrieved 2 definitions.
# Looking up: Otorrhoea
#   → Retrieved 1 definitions.
# Looking up: Otorrhagia
#   → Retrieved 1 definitions.
# Looking up: Otosclerosis
#   → Retrieved 1 definitions.
# Looking up: Lymphadenitis
#   → Retrieved 2 definitions.
# Looking up: Lymphangitis
#   → Retrieved 3 definitions.
# Looking up: Myoendocarditis
#   → Retrieved 0 definitions.
# Looking up: Hypotension
#   → Retrieved 3 definitions.
# Looking up: Pericarditis
#   → Retrieved 2 definitions.
# Looking up: Lipodermatosclerosis
#   → Retrieved 0 definitions.
# Looking up: Cardiomegaly
#   → Retrieved 1 definitions.
# Looking up: Cardiomyopathy
#   → Retrieved 2 definitions.
# Looking up: Myocarditis
#   → Retrieved 1 definitions.
# Looking up: Haemopericardium
#   → Retrieved 1 definitions.
# Looking up: Lymphangiectasia
#   → Retrieved 1 definitions.
# Looking up: Lymphoedema
#   → Retrieved 1 definitions.
# Looking up: Myopericarditis
#   → Retrieved 1 definitions.
# Looking up: Periendocarditis
#   → Retrieved 0 definitions.
# Looking up: Siderosis
#   → Retrieved 2 definitions.
# Looking up: Fibrothorax
#   → Retrieved 0 definitions.
# Looking up: Bagassosis
#   → Retrieved 1 definitions.
# Looking up: Tracheobronchitis
#   → Retrieved 1 definitions.
# Looking up: Asthma
#   → Retrieved 7 definitions.
# Looking up: Bronchiectasis
#   → Retrieved 1 definitions.
# Looking up: Bronchitis
#   → Retrieved 1 definitions.
# Looking up: Suberosis
#   → Retrieved 0 definitions.
# Looking up: Stannosis
#   → Retrieved 0 definitions.
# Looking up: Berylliosis
#   → Retrieved 1 definitions.
# Looking up: Pneumonitis
#   → Retrieved 3 definitions.
# Looking up: Tracheobronchomegaly
#   → Retrieved 0 definitions.
# Looking up: Lymphangioleiomyomatosis
#   → Retrieved 0 definitions.
# Looking up: Haemothorax
#   → Retrieved 1 definitions.
# Looking up: Pneumonia
#   → Retrieved 10 definitions.
# Looking up: Emphysema
#   → Retrieved 2 definitions.
# Looking up: Pneumothorax
#   → Retrieved 2 definitions.
# Looking up: Pyothorax
#   → Retrieved 2 definitions.
# Looking up: Pneumoconiosis
#   → Retrieved 2 definitions.
# Looking up: Hernias
#   → Retrieved 3 definitions.
# Looking up: Gastritis
#   → Retrieved 2 definitions.
# Looking up: Achlorhydria
#   → Retrieved 1 definitions.
# Looking up: Cholelithiasis
#   → Retrieved 1 definitions.
# Looking up: Oesophagitis
#   → Retrieved 1 definitions.
# Looking up: Megaloappendix
#   → Retrieved 0 definitions.
# Looking up: Gastroptosis
#   → Retrieved 1 definitions.
# Looking up: Abfraction
#   → Retrieved 1 definitions.
# Looking up: Sialoadenitis
#   → Retrieved 1 definitions.
# Looking up: Sialolithiasis
#   → Retrieved 1 definitions.
# Looking up: Periodontosis
#   → Retrieved 1 definitions.
# Looking up: Cholecystitis
#   → Retrieved 1 definitions.
# Looking up: Cholangitis
#   → Retrieved 1 definitions.
# Looking up: Malocclusion
#   → Retrieved 1 definitions.
# Looking up: Noma
#   → Retrieved 1 definitions.
# Looking up: Duodenitis
#   → Retrieved 1 definitions.
# Looking up: Achalasia
#   → Retrieved 1 definitions.
# Looking up: Peritonitis
#   → Retrieved 2 definitions.
# Looking up: Appendicitis
#   → Retrieved 1 definitions.
# Looking up: Sialophagia
#   → Retrieved 0 definitions.
# Looking up: Micrognathia
#   → Retrieved 1 definitions.
# Looking up: Pericoronitis
#   → Retrieved 1 definitions.
# Looking up: Sialoschesis
#   → Retrieved 0 definitions.
# Looking up: Xerostomia
#   → Retrieved 1 definitions.
# Looking up: Macroglossia
#   → Retrieved 1 definitions.
# Looking up: Glossitis
#   → Retrieved 1 definitions.
# Looking up: Hypoplasminogenaemia
#   → Retrieved 0 definitions.
# Looking up: Pulpitis
#   → Retrieved 1 definitions.
# Looking up: Haemorrhoids
#   → Retrieved 0 definitions.
# Looking up: Globus
#   → Retrieved 2 definitions.
# Looking up: Cheilitis
#   → Retrieved 1 definitions.
# Looking up: Megacolon
#   → Retrieved 3 definitions.
# Looking up: Gastroparesis
#   → Retrieved 1 definitions.
# Looking up: Haemoperitoneum
#   → Retrieved 1 definitions.
# Looking up: Acne
#   → Retrieved 7 definitions.
# Looking up: Vitiligo
#   → Retrieved 1 definitions.
# Looking up: Freckles
#   → Retrieved 1 definitions.
# Looking up: Lipoedema
#   → Retrieved 0 definitions.
# Looking up: Hyperhidrosis
#   → Retrieved 1 definitions.
# Looking up: Capillaritis
#   → Retrieved 0 definitions.
# Looking up: Miliaria
#   → Retrieved 3 definitions.
# Looking up: Psoriasis
#   → Retrieved 3 definitions.
# Looking up: Sunburn
#   → Retrieved 2 definitions.
# Looking up: Ichthyoses
#   → Retrieved 1 definitions.
# Looking up: Penoscrotodynia
#   → Retrieved 0 definitions.
# Looking up: Pruritus
#   → Retrieved 3 definitions.
# Looking up: Onychomycosis
#   → Retrieved 1 definitions.
# Looking up: Anetoderma
#   → Retrieved 0 definitions.
# Looking up: Morphoea
#   → Retrieved 1 definitions.
# Looking up: Pemphigoid
#   → Retrieved 3 definitions.
# Looking up: Panniculitis
#   → Retrieved 3 definitions.
# Looking up: Keloid
#   → Retrieved 2 definitions.
# Looking up: Poikiloderma
#   → Retrieved 1 definitions.
# Looking up: Dermographism
#   → Retrieved 1 definitions.
# Looking up: Seborrhoea
#   → Retrieved 1 definitions.
# Looking up: Hidrocystoma
#   → Retrieved 0 definitions.
# Looking up: Pseudoporphyria
#   → Retrieved 0 definitions.
# Looking up: Hypohidrosis
#   → Retrieved 1 definitions.
# Looking up: Melanonychia
#   → Retrieved 0 definitions.
# Looking up: Melasma
#   → Retrieved 1 definitions.
# Looking up: Onycholysis
#   → Retrieved 1 definitions.
# Looking up: Cellulite
#   → Retrieved 1 definitions.
# Looking up: Pemphigus
#   → Retrieved 4 definitions.
# Looking up: Prurigo
#   → Retrieved 1 definitions.
# Looking up: Angiokeratoma
#   → Retrieved 1 definitions.
# Looking up: Rosacea
#   → Retrieved 2 definitions.
# Looking up: Hypertrichosis
#   → Retrieved 1 definitions.
# Looking up: Suntan
#   → Retrieved 1 definitions.
# Looking up: Porokeratoses
#   → Retrieved 0 definitions.
# Looking up: Spondylolisthesis
#   → Retrieved 1 definitions.
# Looking up: Osteoarthritis
#   → Retrieved 1 definitions.
# Looking up: Bursitis
#   → Retrieved 2 definitions.
# Looking up: Osteosclerosis
#   → Retrieved 1 definitions.
# Looking up: Tenosynovitis
#   → Retrieved 1 definitions.
# Looking up: Osteoporosis
#   → Retrieved 1 definitions.
# Looking up: Spondylopathies
#   → Retrieved 1 definitions.
# Looking up: Myalgia
#   → Retrieved 2 definitions.
# Looking up: Chondromalacia
#   → Retrieved 2 definitions.
# Looking up: Osteolysis
#   → Retrieved 1 definitions.
# Looking up: Torticollis
#   → Retrieved 3 definitions.
# Looking up: Chondropathies
#   → Retrieved 0 definitions.
# Looking up: Gout
#   → Retrieved 1 definitions.
# Looking up: Metatarsalgia
#   → Retrieved 1 definitions.
# Looking up: Ganglion
#   → Retrieved 14 definitions.
# Looking up: Osteopenia
#   → Retrieved 1 definitions.
# Looking up: Polyosteoarthritis
#   → Retrieved 0 definitions.
# Looking up: Lordosis
#   → Retrieved 2 definitions.
# Looking up: Osteonecrosis
#   → Retrieved 2 definitions.
# Looking up: Scoliosis
#   → Retrieved 1 definitions.
# Looking up: Spondylolysis
#   → Retrieved 1 definitions.
# Looking up: Oligoosteoarthritis
#   → Retrieved 0 definitions.
# Looking up: Arthropathies
#   → Retrieved 1 definitions.
# Looking up: Chondrocalcinosis
#   → Retrieved 1 definitions.
# Looking up: Osteophyte
#   → Retrieved 1 definitions.
# Looking up: Kyphosis
#   → Retrieved 1 definitions.
# Looking up: Vulvodynia
#   → Retrieved 1 definitions.
# Looking up: Haematometra
#   → Retrieved 1 definitions.
# Looking up: Menopause
#   → Retrieved 6 definitions.
# Looking up: Vulvitis
#   → Retrieved 1 definitions.
# Looking up: Pyonephrosis
#   → Retrieved 1 definitions.
# Looking up: Urolithiasis
#   → Retrieved 1 definitions.
# Looking up: Amenorrhoea
#   → Retrieved 1 definitions.
# Looking up: Cystitis
#   → Retrieved 2 definitions.
# Looking up: Cervicitis
#   → Retrieved 1 definitions.
# Looking up: Aminoaciduria
#   → Retrieved 1 definitions.
# Looking up: Dyspareunia
#   → Retrieved 1 definitions.
# Looking up: Vaginitis
#   → Retrieved 5 definitions.
# Looking up: Nephrocalcinosis
#   → Retrieved 1 definitions.
# Looking up: Phimosis
#   → Retrieved 1 definitions.
# Looking up: Mastodynia
#   → Retrieved 1 definitions.
# Looking up: Haematocolpos
#   → Retrieved 1 definitions.
# Looking up: Dysmenorrhoea
#   → Retrieved 1 definitions.
# Looking up: Priapism
#   → Retrieved 1 definitions.
# Looking up: Azoospermia
#   → Retrieved 1 definitions.
# Looking up: Haematosalpinx
#   → Retrieved 1 definitions.
# Looking up: Nephronophthisis
#   → Retrieved 0 definitions.
# Looking up: Spermatocele
#   → Retrieved 1 definitions.
# Looking up: Nephroptosis
#   → Retrieved 1 definitions.
# Looking up: Hydroureter
#   → Retrieved 1 definitions.
# Looking up: Trigonitis
#   → Retrieved 1 definitions.
# Looking up: Hydrosalpinx
#   → Retrieved 1 definitions.
# Looking up: Paraphimosis
#   → Retrieved 1 definitions.
# Looking up: Prostatocystitis
#   → Retrieved 0 definitions.
# Looking up: Endometriosis
#   → Retrieved 1 definitions.
# Looking up: Adenomyosis
#   → Retrieved 1 definitions.
# Looking up: Anorgasmia
#   → Retrieved 1 definitions.
# Looking up: Eclampsia
#   → Retrieved 3 definitions.
# Looking up: Galactorrhoea
#   → Retrieved 1 definitions.
# Looking up: Delivery
#   → Retrieved 6 definitions.
# Looking up: Hypogalactia
#   → Retrieved 1 definitions.
# Looking up: Oligohydramnios
#   → Retrieved 1 definitions.
# Looking up: Abortion
#   → Retrieved 14 definitions.
# Looking up: Agalactia
#   → Retrieved 1 definitions.
# Looking up: Pre-eclampsia
#   → Retrieved 2 definitions.
# Looking up: Hepatoblastoma
#   → Retrieved 1 definitions.
# Looking up: Lipoblastoma
#   → Retrieved 0 definitions.
# Looking up: Meningiomas
#   → Retrieved 1 definitions.
# Looking up: Mastocytosis
#   → Retrieved 1 definitions.
# Looking up: Dermatofibroma
#   → Retrieved 1 definitions.
# Looking up: Keratoacanthoma
#   → Retrieved 1 definitions.
# Looking up: Thymoma
#   → Retrieved 1 definitions.
# Looking up: Lipoma
#   → Retrieved 1 definitions.
# Looking up: Neoplasms
#   → Retrieved 1 definitions.
# Looking up: Retinoblastoma
#   → Retrieved 1 definitions.
# Looking up: Rhabdomyoma
#   → Retrieved 1 definitions.
# Looking up: Laevocardia
#   → Retrieved 1 definitions.
# Looking up: Microstomia
#   → Retrieved 1 definitions.
# Looking up: Oligodontia
#   → Retrieved 0 definitions.
# Looking up: Acheiria
#   → Retrieved 0 definitions.
# Looking up: Hyperdontia
#   → Retrieved 0 definitions.
# Looking up: Osteopoikilosis
#   → Retrieved 1 definitions.
# Looking up: Hypochondrogenesis
#   → Retrieved 0 definitions.
# Looking up: Schizencephaly
#   → Retrieved 0 definitions.
# Looking up: Craniosynostosis
#   → Retrieved 1 definitions.
# Looking up: Dextrocardia
#   → Retrieved 1 definitions.
# Looking up: Iridoschisis
#   → Retrieved 1 definitions.
# Looking up: Gastroschisis
#   → Retrieved 1 definitions.
# Looking up: Hypochondroplasia
#   → Retrieved 0 definitions.
# Looking up: Megalopapilla
#   → Retrieved 0 definitions.
# Looking up: Clitoromegaly
#   → Retrieved 0 definitions.
# Looking up: Aniridia
#   → Retrieved 1 definitions.
# Looking up: Holoprosencephaly
#   → Retrieved 0 definitions.
# Looking up: Polydactyly
#   → Retrieved 1 definitions.
# Looking up: Amyelencephaly
#   → Retrieved 0 definitions.
# Looking up: Polysplenia
#   → Retrieved 0 definitions.
# Looking up: Sirenomelia
#   → Retrieved 1 definitions.
# Looking up: Osteopetrosis
#   → Retrieved 3 definitions.
# Looking up: Microphthalmos
#   → Retrieved 1 definitions.
# Looking up: Mesocardia
#   → Retrieved 1 definitions.
# Looking up: Hypospadias
#   → Retrieved 2 definitions.
# Looking up: Syndactyly
#   → Retrieved 1 definitions.
# Looking up: Hyperphalangy
#   → Retrieved 0 definitions.
# Looking up: Megalencephaly
#   → Retrieved 0 definitions.
# Looking up: Polyorchidism
#   → Retrieved 1 definitions.
# Looking up: Oligomeganephronia
#   → Retrieved 0 definitions.
# Looking up: Laryngocele
#   → Retrieved 1 definitions.
# Looking up: Ankyloglossia
#   → Retrieved 1 definitions.
# Looking up: Macrocephaly
#   → Retrieved 1 definitions.
# Looking up: Colpocephaly
#   → Retrieved 0 definitions.
# Looking up: Megacystis-megaureter
#   → Retrieved 0 definitions.
# Looking up: Cephalocele
#   → Retrieved 0 definitions.
# Looking up: Brachydactyly
#   → Retrieved 1 definitions.
# Looking up: Polymicrogyria
#   → Retrieved 0 definitions.
# Looking up: Tetraploidy
#   → Retrieved 1 definitions.
# Looking up: Triploidy
#   → Retrieved 1 definitions.
# Looking up: Macrotia
#   → Retrieved 1 definitions.
# Looking up: Apodia
#   → Retrieved 0 definitions.
# Looking up: Hydranencephaly
#   → Retrieved 1 definitions.
# Looking up: Arrhinencephaly
#   → Retrieved 0 definitions.
# Looking up: Acephaly
#   → Retrieved 0 definitions.
# Looking up: Hypodontia
#   → Retrieved 1 definitions.
# Looking up: Microcheilia
#   → Retrieved 0 definitions.
# Looking up: Iniencephaly
#   → Retrieved 1 definitions.
# Looking up: Plagiocephaly
#   → Retrieved 1 definitions.
# Looking up: Cherubism
#   → Retrieved 1 definitions.
# Looking up: Macrostomia
#   → Retrieved 2 definitions.
# Looking up: Hypertelorism
#   → Retrieved 1 definitions.
# Looking up: Pseudoachondroplasia
#   → Retrieved 0 definitions.
# Looking up: Otocephaly
#   → Retrieved 1 definitions.
# Looking up: Omphalocele
#   → Retrieved 1 definitions.
# Looking up: Cryptorchidism
#   → Retrieved 1 definitions.
# Looking up: Diastematomyelia
#   → Retrieved 1 definitions.
# Looking up: Arrhinia
#   → Retrieved 0 definitions.
# Looking up: Buphthalmos
#   → Retrieved 1 definitions.
# Looking up: Achondroplasia
#   → Retrieved 2 definitions.
# Looking up: Porencephaly
#   → Retrieved 1 definitions.
# Looking up: Microcephaly
#   → Retrieved 1 definitions.
# Looking up: Achondrogenesis
#   → Retrieved 1 definitions.
# Looking up: Hypotelorism
#   → Retrieved 0 definitions.
# Looking up: Epispadias
#   → Retrieved 1 definitions.
# Looking up: Cryptophthalmia
#   → Retrieved 0 definitions.
# Looking up: Microtia
#   → Retrieved 1 definitions.
# Looking up: Craniorachischisis
#   → Retrieved 1 definitions.
# Looking up: Anotia
#   → Retrieved 1 definitions.
# Looking up: Anencephaly
#   → Retrieved 1 definitions.
# Looking up: Polyploidies
#   → Retrieved 2 definitions.
# Looking up: Neurofibromatoses
#   → Retrieved 2 definitions.
# Looking up: Amyelia
#   → Retrieved 1 definitions.
# Looking up: Anodontia
#   → Retrieved 1 definitions.
# Looking up: Macrocheilia
#   → Retrieved 0 definitions.
# Looking up: Polysyndactyly
#   → Retrieved 0 definitions.
# Looking up: Spherophakia
#   → Retrieved 1 definitions.
# Looking up: Myelocystocele
#   → Retrieved 0 definitions.
# Looking up: Neologisms
#   → Retrieved 1 definitions.
# Looking up: Irritability
#   → Retrieved 3 definitions.
# Looking up: Haematemesis
#   → Retrieved 1 definitions.
# Looking up: Tangentiality
#   → Retrieved 0 definitions.
# Looking up: Titubation
#   → Retrieved 1 definitions.
# Looking up: Acroparaesthesia
#   → Retrieved 1 definitions.
# Looking up: Anosognosia
#   → Retrieved 1 definitions.
# Looking up: Myotonia
#   → Retrieved 3 definitions.
# Looking up: Clonus
#   → Retrieved 1 definitions.
# Looking up: Asphyxia
#   → Retrieved 1 definitions.
# Looking up: Pleurisy
#   → Retrieved 9 definitions.
# Looking up: Hostility
#   → Retrieved 1 definitions.
# Looking up: Dysphasia
#   → Retrieved 3 definitions.
# Looking up: Paraplegia
#   → Retrieved 2 definitions.
# Looking up: Rash
#   → Retrieved 8 definitions.
# Looking up: Athetosis
#   → Retrieved 1 definitions.
# Looking up: Incoherence
#   → Retrieved 1 definitions.
# Looking up: Grandiosity
#   → Retrieved 1 definitions.
# Looking up: Perseveration
#   → Retrieved 1 definitions.
# Looking up: Constipation
#   → Retrieved 1 definitions.
# Looking up: Negativism
#   → Retrieved 2 definitions.
# Looking up: Pyuria
#   → Retrieved 1 definitions.
# Looking up: Phonophobia
#   → Retrieved 2 definitions.
# Looking up: Hopelessness
#   → Retrieved 0 definitions.
# Looking up: Myoglobinuria
#   → Retrieved 1 definitions.
# Looking up: Hyperaesthesia
#   → Retrieved 1 definitions.
# Looking up: Eccentricity
#   → Retrieved 0 definitions.
# Looking up: Epiphora
#   → Retrieved 1 definitions.
# Looking up: Quadrantanopia
#   → Retrieved 0 definitions.
# Looking up: Bacteraemia
#   → Retrieved 1 definitions.
# Looking up: Anacusis
#   → Retrieved 0 definitions.
# Looking up: Parosmia
#   → Retrieved 1 definitions.
# Looking up: Cyanosis
#   → Retrieved 1 definitions.
# Looking up: Cough
#   → Retrieved 8 definitions.
# Looking up: Presyncope
#   → Retrieved 0 definitions.
# Looking up: Dysphagia
#   → Retrieved 1 definitions.
# Looking up: Agnosia
#   → Retrieved 2 definitions.
# Looking up: Heartburn
#   → Retrieved 1 definitions.
# Looking up: Dysphonia
#   → Retrieved 1 definitions.
# Looking up: Rumination-regurgitation
#   → Retrieved 0 definitions.
# Looking up: Anosmia
#   → Retrieved 1 definitions.
# Looking up: Diarrhoea
#   → Retrieved 1 definitions.
# Looking up: Dysesthesia
#   → Retrieved 1 definitions.
# Looking up: Worry
#   → Retrieved 1 definitions.
# Looking up: Gangrene
#   → Retrieved 8 definitions.
# Looking up: Tiredness
#   → Retrieved 1 definitions.
# Looking up: Stridor
#   → Retrieved 1 definitions.
# Looking up: Proteinuria
#   → Retrieved 1 definitions.
# Looking up: Echolalia
#   → Retrieved 1 definitions.
# Looking up: Tetany
#   → Retrieved 3 definitions.
# Looking up: Illusions
#   → Retrieved 3 definitions.
# Looking up: Belching
#   → Retrieved 2 definitions.
# Looking up: Automatism
#   → Retrieved 2 definitions.
# Looking up: Melaena
#   → Retrieved 1 definitions.
# Looking up: Obsessions
#   → Retrieved 1 definitions.
# Looking up: Pain
#   → Retrieved 11 definitions.
# Looking up: Ophthalmoparesis
#   → Retrieved 0 definitions.
# Looking up: Glycosuria
#   → Retrieved 3 definitions.
# Looking up: Demoralization
#   → Retrieved 0 definitions.
# Looking up: Shuddering
#   → Retrieved 1 definitions.
# Looking up: Petechiae
#   → Retrieved 1 definitions.
# Looking up: Haematochezia
#   → Retrieved 1 definitions.
# Looking up: Dysuria
#   → Retrieved 1 definitions.
# Looking up: Dyspepsia
#   → Retrieved 1 definitions.
# Looking up: Dysarthria
#   → Retrieved 1 definitions.
# Looking up: Wetting
#   → Retrieved 2 definitions.
# Looking up: Dyssomnia
#   → Retrieved 0 definitions.
# Looking up: Acalculia
#   → Retrieved 1 definitions.
# Looking up: Allodynia
#   → Retrieved 1 definitions.
# Looking up: Dysgeusia
#   → Retrieved 1 definitions.
# Looking up: Opisthotonos
#   → Retrieved 1 definitions.
# Looking up: Sleeptalking
#   → Retrieved 0 definitions.
# Looking up: Oedema
#   → Retrieved 3 definitions.
# Looking up: Analgesia
#   → Retrieved 2 definitions.
# Looking up: Delusion
#   → Retrieved 7 definitions.
# Looking up: Amnesia
#   → Retrieved 4 definitions.
# Looking up: Euphoria
#   → Retrieved 3 definitions.
# Looking up: Apraxia
#   → Retrieved 1 definitions.
# Looking up: Erythema
#   → Retrieved 10 definitions.
# Looking up: Hypokaluria
#   → Retrieved 0 definitions.
# Looking up: Dyspnoea
#   → Retrieved 1 definitions.
# Looking up: Immobility
#   → Retrieved 2 definitions.
# Looking up: Apnoea
#   → Retrieved 2 definitions.
# Looking up: Suspiciousness
#   → Retrieved 0 definitions.
# Looking up: Hemiplegia
#   → Retrieved 1 definitions.
# Looking up: Apathy
#   → Retrieved 1 definitions.
# Looking up: Tantrum
#   → Retrieved 1 definitions.
# Looking up: Aphonia
#   → Retrieved 1 definitions.
# Looking up: Distractibility
#   → Retrieved 4 definitions.
# Looking up: Anxiety
#   → Retrieved 13 definitions.
# Looking up: Agraphia
#   → Retrieved 1 definitions.
# Looking up: Nasality
#   → Retrieved 1 definitions.
# Looking up: Polydipsia
#   → Retrieved 1 definitions.
# Looking up: Ambivalence
#   → Retrieved 2 definitions.
# Looking up: Mutism
#   → Retrieved 4 definitions.
# Looking up: Overeating
#   → Retrieved 3 definitions.
# Looking up: Fear
#   → Retrieved 2 definitions.
# Looking up: Nausea
#   → Retrieved 2 definitions.
# Looking up: Tinnitus
#   → Retrieved 1 definitions.
# Looking up: Hypocalciuria
#   → Retrieved 0 definitions.
# Looking up: Recklessness
#   → Retrieved 0 definitions.
# Looking up: Vomiting
#   → Retrieved 6 definitions.
# Looking up: Wheezing
#   → Retrieved 1 definitions.
# Looking up: Dystonia
#   → Retrieved 4 definitions.
# Looking up: Atonia
#   → Retrieved 1 definitions.
# Looking up: Hypomagnesuria
#   → Retrieved 0 definitions.
# Looking up: Entitlement
#   → Retrieved 0 definitions.
# Looking up: Pollakiuria
#   → Retrieved 1 definitions.
# Looking up: Shock
#   → Retrieved 13 definitions.
# Looking up: Perfectionism
#   → Retrieved 1 definitions.
# Looking up: Stupor
#   → Retrieved 1 definitions.
# Looking up: Circumstantiality
#   → Retrieved 1 definitions.
# Looking up: Cachexia
#   → Retrieved 2 definitions.
# Looking up: Coma
#   → Retrieved 5 definitions.
# Looking up: Haematuria
#   → Retrieved 1 definitions.
# Looking up: Irresponsibility
#   → Retrieved 1 definitions.
# Looking up: Chyluria
#   → Retrieved 1 definitions.
# Looking up: Bradyphrenia
#   → Retrieved 1 definitions.
# Looking up: Pessimism
#   → Retrieved 1 definitions.
# Looking up: Coprolalia
#   → Retrieved 2 definitions.
# Looking up: Hyperkaluria
#   → Retrieved 0 definitions.
# Looking up: Impulsivity
#   → Retrieved 3 definitions.
# Looking up: Chills
#   → Retrieved 5 definitions.
# Looking up: Dyscalculia
#   → Retrieved 1 definitions.
# Looking up: Hypercalciuria
#   → Retrieved 1 definitions.
# Looking up: Soiling
#   → Retrieved 0 definitions.
# Looking up: Staphyloma
#   → Retrieved 1 definitions.
# Looking up: Stubbornness
#   → Retrieved 0 definitions.
# Looking up: Hypopyon
#   → Retrieved 1 definitions.
# Looking up: Anger
#   → Retrieved 0 definitions.
# Looking up: Confabulation
#   → Retrieved 1 definitions.
# Looking up: Hypophosphaturia
#   → Retrieved 0 definitions.
# Looking up: Flushing
#   → Retrieved 2 definitions.
# Looking up: Acetonuria
#   → Retrieved 2 definitions.
# Looking up: Sciatica
#   → Retrieved 1 definitions.
# Looking up: Hiccough
#   → Retrieved 3 definitions.
# Looking up: Asterixis
#   → Retrieved 1 definitions.
# Looking up: Fungaemia
#   → Retrieved 1 definitions.
# Looking up: Hangover
#   → Retrieved 1 definitions.
# Looking up: Polyuria
#   → Retrieved 1 definitions.
# Looking up: Hyperventilation
#   → Retrieved 1 definitions.
# Looking up: Tetraplegia
#   → Retrieved 2 definitions.
# Looking up: Ascites
#   → Retrieved 1 definitions.
# Looking up: Rales
#   → Retrieved 2 definitions.
# Looking up: Yawning
#   → Retrieved 1 definitions.
# Looking up: Palpitations
#   → Retrieved 2 definitions.
# Looking up: Epistaxis
#   → Retrieved 2 definitions.
# Looking up: Bilirubinuria
#   → Retrieved 1 definitions.
# Looking up: Stertor
#   → Retrieved 1 definitions.
# Looking up: Fatigue
#   → Retrieved 11 definitions.
# Looking up: Derealisation
#   → Retrieved 1 definitions.
# Looking up: Anorexia
#   → Retrieved 5 definitions.
# Looking up: Halitosis
#   → Retrieved 1 definitions.
# Looking up: Aphasia
#   → Retrieved 10 definitions.
# Looking up: Vertigo
#   → Retrieved 6 definitions.
# Looking up: Pallor
#   → Retrieved 1 definitions.
# Looking up: Aura
#   → Retrieved 1 definitions.
# Looking up: Anomia
#   → Retrieved 2 definitions.
# Looking up: Hoarseness
#   → Retrieved 2 definitions.
# Looking up: Avolition
#   → Retrieved 1 definitions.
# Looking up: Hallucinations
#   → Retrieved 2 definitions.
# Looking up: Anarthria
#   → Retrieved 1 definitions.
# Looking up: Asomatognosia
#   → Retrieved 0 definitions.
# Looking up: Anhedonia
#   → Retrieved 1 definitions.
# Looking up: Callousness
#   → Retrieved 2 definitions.
# Looking up: Hyposmia
#   → Retrieved 1 definitions.
# Looking up: Disorientation
#   → Retrieved 1 definitions.
# Looking up: Dysphoria
#   → Retrieved 3 definitions.
# Looking up: Haemoptysis
#   → Retrieved 1 definitions.
# Looking up: Compulsions
#   → Retrieved 2 definitions.
# Looking up: Fasciculation
#   → Retrieved 1 definitions.
# Looking up: Submissiveness
#   → Retrieved 1 definitions.
# Looking up: Depersonalisation
#   → Retrieved 1 definitions.
# Looking up: Meningismus
#   → Retrieved 2 definitions.
# Looking up: Haemoglobinuria
#   → Retrieved 1 definitions.
# Looking up: Restlessness
#   → Retrieved 2 definitions.
# Looking up: Hypermagnesuria
#   → Retrieved 0 definitions.
# Looking up: Sneezing
#   → Retrieved 2 definitions.
# Looking up: Indecisiveness
#   → Retrieved 0 definitions.
# Looking up: Light-headedness
#   → Retrieved 1 definitions.
# Looking up: Abulia
#   → Retrieved 1 definitions.
# Looking up: Hypothermia
#   → Retrieved 1 definitions.
# Looking up: Chilblains
#   → Retrieved 1 definitions.
# Looking up: Burns
#   → Retrieved 10 definitions.
# Looking up: Trichobezoar
#   → Retrieved 2 definitions.
# Looking up: Asphyxiation
#   → Retrieved 2 definitions.
# Looking up: Concussion
#   → Retrieved 2 definitions.
# Looking up: Frostbite
#   → Retrieved 2 definitions.
# Looking up: Assault
#   → Retrieved 2 definitions.
# Looking up: Maltreatment
#   → Retrieved 0 definitions.
# Looking up: Isolation
#   → Retrieved 3 definitions.
# Looking up: Homelessness
#   → Retrieved 0 definitions.
# Looking up: Convalescence
#   → Retrieved 3 definitions.
# Looking up: Psychotherapy
#   → Retrieved 5 definitions.
# Looking up: Poverty
#   → Retrieved 1 definitions.
# Looking up: Burnout
#   → Retrieved 3 definitions.
# Looking up: Apheresis
#   → Retrieved 1 definitions.
# Looking up: Malingering
#   → Retrieved 1 definitions.
# Looking up: COVID-19
#   → Retrieved 4 definitions.
# Looking up: Hypersplenism
#   → Retrieved 1 definitions.
# Looking up: Splenosis
#   → Retrieved 1 definitions.
# Looking up: Perisplenitis
#   → Retrieved 1 definitions.
# Looking up: Hyperhomocysteinaemia
#   → Retrieved 0 definitions.
# Looking up: Polycythaemia
#   → Retrieved 1 definitions.
# Looking up: Thalassaemias
#   → Retrieved 0 definitions.
# Looking up: Thrombophilia
#   → Retrieved 3 definitions.
# Looking up: Thrombocytosis
#   → Retrieved 1 definitions.
# Looking up: Thrombocytopenia
#   → Retrieved 1 definitions.
# Looking up: Anaphylaxis
#   → Retrieved 4 definitions.
# Looking up: Cryoglobulinaemia
#   → Retrieved 1 definitions.
# Looking up: Vasculitis
#   → Retrieved 5 definitions.
# Looking up: Neurosarcoidosis
#   → Retrieved 0 definitions.
# Looking up: Polymyositis
#   → Retrieved 1 definitions.
# Looking up: Eosinopenia
#   → Retrieved 1 definitions.
# Looking up: Neutrophilia
#   → Retrieved 1 definitions.
# Looking up: Sarcoidosis
#   → Retrieved 1 definitions.
# Looking up: Eosinophilia
#   → Retrieved 4 definitions.
# Looking up: Dermatomyositis
#   → Retrieved 1 definitions.
# Looking up: Neutropenia
#   → Retrieved 2 definitions.
# Looking up: Pseudohypoparathyroidism
#   → Retrieved 2 definitions.
# Looking up: Obesity
#   → Retrieved 2 definitions.
# Looking up: Hyperaldosteronism
#   → Retrieved 2 definitions.
# Looking up: Overweight
#   → Retrieved 1 definitions.
# Looking up: Thyroiditis
#   → Retrieved 2 definitions.
# Looking up: Hypopituitarism
#   → Retrieved 1 definitions.
# Looking up: Hypoalphalipoproteinaemia
#   → Retrieved 0 definitions.
# Looking up: Hyperprolactinaemia
#   → Retrieved 1 definitions.
# Looking up: Hypokalaemia
#   → Retrieved 1 definitions.
# Looking up: Cystinuria
#   → Retrieved 1 definitions.
# Looking up: Hypobetalipoproteinaemia
#   → Retrieved 0 definitions.
# Looking up: Porphyrias
#   → Retrieved 1 definitions.
# Looking up: Histidinaemia
#   → Retrieved 1 definitions.
# Looking up: Trimethylaminuria
#   → Retrieved 0 definitions.
# Looking up: Beriberi
#   → Retrieved 1 definitions.
# Looking up: Homocarnosinosis
#   → Retrieved 0 definitions.
# Looking up: Hypercalcaemia
#   → Retrieved 1 definitions.
# Looking up: Scurvy
#   → Retrieved 3 definitions.
# Looking up: Sphingolipidosis
#   → Retrieved 1 definitions.
# Looking up: Hypercholesterolaemia
#   → Retrieved 1 definitions.
# Looking up: Alkaptonuria
#   → Retrieved 2 definitions.
# Looking up: Hypothyroidism
#   → Retrieved 1 definitions.
# Looking up: Mucopolysaccharidosis
#   → Retrieved 1 definitions.
# Looking up: Dehydration
#   → Retrieved 1 definitions.
# Looking up: Anovulation
#   → Retrieved 1 definitions.
# Looking up: Xanthinuria
#   → Retrieved 0 definitions.
# Looking up: Sarcosinaemia
#   → Retrieved 0 definitions.
# Looking up: Amyloidosis
#   → Retrieved 1 definitions.
# Looking up: Cystinosis
#   → Retrieved 1 definitions.
# Looking up: Pellagra
#   → Retrieved 2 definitions.
# Looking up: Hypomagnesaemia
#   → Retrieved 1 definitions.
# Looking up: Hyperparathyroidism
#   → Retrieved 1 definitions.
# Looking up: Alkalosis
#   → Retrieved 3 definitions.
# Looking up: Phenylketonuria
#   → Retrieved 1 definitions.
# Looking up: Gangliosidosis
#   → Retrieved 1 definitions.
# Looking up: Hypercarotenaemia
#   → Retrieved 0 definitions.
# Looking up: Hypertriglyceridaemia
#   → Retrieved 1 definitions.
# Looking up: Hyperlipoproteinaemia
#   → Retrieved 1 definitions.
# Looking up: Hypolipoproteinaemia
#   → Retrieved 0 definitions.
# Looking up: Mucolipidosis
#   → Retrieved 1 definitions.
# Looking up: Acidosis
#   → Retrieved 5 definitions.
# Looking up: Argininaemia
#   → Retrieved 0 definitions.
# Looking up: Hypoaldosteronism
#   → Retrieved 0 definitions.
# Looking up: Oligo-ovulation
#   → Retrieved 0 definitions.
# Looking up: Hyperalphalipoproteinaemia
#   → Retrieved 0 definitions.
# Looking up: Glycoproteinosis
#   → Retrieved 0 definitions.
# Looking up: Hypoparathyroidism
#   → Retrieved 1 definitions.
# Looking up: Citrullinaemia
#   → Retrieved 1 definitions.
# Looking up: Hypermagnesaemia
#   → Retrieved 1 definitions.
# Looking up: Carnosinaemia
#   → Retrieved 0 definitions.
# Looking up: Thyrotoxicosis
#   → Retrieved 2 definitions.
# Looking up: Hypovolaemia
#   → Retrieved 1 definitions.
# Looking up: Oligosaccharidosis
#   → Retrieved 0 definitions.
# Looking up: Undernutrition
#   → Retrieved 1 definitions.
# Looking up: Hyperkalaemia
#   → Retrieved 1 definitions.
# Looking up: Kleptomania
#   → Retrieved 1 definitions.
# Looking up: Catatonia
#   → Retrieved 1 definitions.
# Looking up: Encopresis
#   → Retrieved 1 definitions.
# Looking up: Dementia
#   → Retrieved 10 definitions.
# Looking up: Trichotillomania
#   → Retrieved 1 definitions.
# Looking up: Pyromania
#   → Retrieved 2 definitions.
# Looking up: Delirium
#   → Retrieved 2 definitions.
# Looking up: Enuresis
#   → Retrieved 1 definitions.
# Looking up: Hypochondriasis
#   → Retrieved 1 definitions.
# Looking up: Agoraphobia
#   → Retrieved 2 definitions.
# Looking up: Pica
#   → Retrieved 1 definitions.
# Looking up: Schizophrenia
#   → Retrieved 3 definitions.
# Looking up: Narcolepsy
#   → Retrieved 1 definitions.
# Looking up: Syringobulbia
#   → Retrieved 1 definitions.
# Looking up: Stereotypies
#   → Retrieved 1 definitions.
# Looking up: Kuru
#   → Retrieved 1 definitions.
# Looking up: Akathisia
#   → Retrieved 1 definitions.
# Looking up: Dystonia-plus
#   → Retrieved 0 definitions.
# Looking up: Pachymeningitis
#   → Retrieved 1 definitions.
# Looking up: Myelitis
#   → Retrieved 2 definitions.
# Looking up: Hemiballism
#   → Retrieved 1 definitions.
# Looking up: Parkinsonism
#   → Retrieved 3 definitions.
# Looking up: Radiculopathy
#   → Retrieved 1 definitions.
# Looking up: Arachnoiditis
#   → Retrieved 1 definitions.
# Looking up: Ballism
#   → Retrieved 1 definitions.
# Looking up: Mononeuropathy
#   → Retrieved 3 definitions.
# Looking up: Hydrocephalus
#   → Retrieved 2 definitions.
# Looking up: Migraine
#   → Retrieved 6 definitions.
# Looking up: Neuromyotonia
#   → Retrieved 0 definitions.
# Looking up: Leukodystrophies
#   → Retrieved 1 definitions.
# Looking up: Pseudomyotonia
#   → Retrieved 0 definitions.
# Looking up: Polyneuropathy
#   → Retrieved 1 definitions.
# Looking up: Hemichorea
#   → Retrieved 1 definitions.
# Looking up: Adrenoleukodystrophy
#   → Retrieved 1 definitions.
# Looking up: Myelopathy
#   → Retrieved 1 definitions.
# Looking up: Chalazion
#   → Retrieved 1 definitions.
# Looking up: Aniseikonia
#   → Retrieved 1 definitions.
# Looking up: Blepharoptosis
#   → Retrieved 1 definitions.
# Looking up: Myopia
#   → Retrieved 1 definitions.
# Looking up: Aphakia
#   → Retrieved 1 definitions.
# Looking up: Pterygium
#   → Retrieved 2 definitions.
# Looking up: Astigmatism
#   → Retrieved 2 definitions.
# Looking up: Dacryolith
#   → Retrieved 1 definitions.
# Looking up: Blepharoconjunctivitis
#   → Retrieved 1 definitions.
# Looking up: Keratoconus
#   → Retrieved 1 definitions.
# Looking up: Telecanthus
#   → Retrieved 0 definitions.
# Looking up: Blindness
#   → Retrieved 12 definitions.
# Looking up: Episcleritis
#   → Retrieved 1 definitions.
# Looking up: Nystagmus
#   → Retrieved 3 definitions.
# Looking up: Retinopathy
#   → Retrieved 4 definitions.
# Looking up: Conjunctivitis
#   → Retrieved 7 definitions.
# Looking up: Hyperlacrimation
#   → Retrieved 0 definitions.
# Looking up: Anisometropia
#   → Retrieved 1 definitions.
# Looking up: Retinoschisis
#   → Retrieved 1 definitions.
# Looking up: Heterophoria
#   → Retrieved 1 definitions.
# Looking up: Glaucoma
#   → Retrieved 5 definitions.
# Looking up: Presbyopia
#   → Retrieved 1 definitions.
# Looking up: Hypermetropia
#   → Retrieved 2 definitions.
# Looking up: Pingueculae
#   → Retrieved 1 definitions.
# Looking up: Endophthalmitis
#   → Retrieved 1 definitions.
# Looking up: Conjunctivochalasis
#   → Retrieved 0 definitions.
# Looking up: Hyphaema
#   → Retrieved 1 definitions.
# Looking up: Blepharochalasis
#   → Retrieved 0 definitions.
# Looking up: Scleritis
#   → Retrieved 1 definitions.
# Looking up: Panuveitis
#   → Retrieved 0 definitions.
# Looking up: Hordeolum
#   → Retrieved 2 definitions.
# Looking up: Papilloedema
#   → Retrieved 1 definitions.
# Looking up: Canaliculitis
#   → Retrieved 0 definitions.
# Looking up: After-cataract
#   → Retrieved 1 definitions.
# Looking up: Exotropia
#   → Retrieved 4 definitions.
# Looking up: Neuroretinitis
#   → Retrieved 1 definitions.
# Looking up: Esotropia
#   → Retrieved 3 definitions.
# Looking up: Dacryocystitis
#   → Retrieved 1 definitions.
# Looking up: Lagophthalmos
#   → Retrieved 1 definitions.
# Looking up: Cataract
#   → Retrieved 3 definitions.
# Done! Results in diseases_definitions.csv

# %%
diseases_definitions = pd.read_csv("diseases_definitions.csv").dropna()

# Merge ICD codes from one_word_titles into diseases_definitions based on the disease name
diseases_definitions = diseases_definitions.merge(
    one_word_titles.rename(columns={'title': 'Disease', 'code': 'ICD_Code'}),
    on='Disease',
    how='left'
)

# Filter for diseases with only one definition (no ';' in Definitions)
single_definition = diseases_definitions[~diseases_definitions['Definitions'].str.contains(';')].copy()
single_definition.reset_index(drop=True, inplace=True)
print(f"Number of diseases with a single definition: {len(single_definition)}")
single_definition.head(10)
# Out:
# Number of diseases with a single definition: 388
#              Disease                                        Definitions  \
# 0      Toxoplasmosis  infection with or disease caused by a sporozoa...
# 1     Rickettsialpox  a disease characterized by fever, chills, head...
# 2      Leptospirosis  any of several diseases of humans and domestic...
# 3      Clonorchiasis  infestation with or disease caused by the Chin...
# 4         Giardiasis  infestation with or disease caused by a flagel...
# 5    Gnathostomiasis  infestation with or disease caused by nematode...
# 6         Ascariasis     infestation with or disease caused by ascarids
# 7  Cryptosporidiosis  infection with or disease caused by cryptospor...
# 8      Helminthiases  infestation with or disease caused by parasiti...
# 9              Mumps  an acute contagious virus disease caused by a ...
#
#   ICD_Code
# 0     1F57
# 1     1C32
# 2     1B91
# 3     1F80
# 4     1A31
# 5     1F67
# 6     1F62
# 7     1A32
# 8      NaN
# 9     1D80

# %%
single_definition[['ICD_Code', 'Definitions']].to_csv('single_definition_no_disease.csv', index=False)
